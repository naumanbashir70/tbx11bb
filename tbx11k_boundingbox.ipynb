# %% [markdown]
# # tbx11k Bounding Box

# %% [markdown]
# ## For single Image

# %%
import xml.etree.ElementTree as ET
import cv2
from matplotlib import pyplot as plt
from PIL import Image
import os, sys

# %%
def read_content(xml_file: str):

    tree = ET.parse(xml_file)
    root = tree.getroot()

    list_with_all_boxes = []

    for boxes in root.iter('object'):

        filename = root.find('filename').text

        ymin, xmin, ymax, xmax = None, None, None, None

        ymin = int(boxes.find("bndbox/ymin").text)
        xmin = int(boxes.find("bndbox/xmin").text)
        ymax = int(boxes.find("bndbox/ymax").text)
        xmax = int(boxes.find("bndbox/xmax").text)

        list_with_single_boxes = [xmin, ymin, xmax, ymax]
        list_with_all_boxes.append(list_with_single_boxes)
    
    return filename, list_with_all_boxes

# %%
img = "tb0003.png"   #image name
xml = "tb0003.xml"   #corresponding xml

# %%
image = cv2.imread(img) 

#Comment the below line if you using High-resolution(3000 × 3000) dataset.
image = cv2.resize(image, (2840, 2827)) 
name, boxes = read_content(xml)

temp = []

for i in range(len(boxes)):
    
    temp = boxes[i]
    
    start_point = (temp[0], temp[3]) 
    end_point = (temp[2], temp[1]) 
      
    
    # Set color in BGR
    if i==0:
        color = (255, 0, 0)
    if i==1:
        color = (0, 255, 0)
    
    # Line thickness of 10 px 
    thickness = 10
    
    # Using cv2.rectangle() method 
    # Draw a rectangle with blue line borders of thickness of 2 px 
   
    image = cv2.rectangle(image, start_point, end_point, color, thickness)
# Out:
# ======== tb0003

# %%
#Comment the below line if you using High-resolution(3000 × 3000) dataset.
image = cv2.resize(image, (512, 512)) 

cv2.imwrite("img_bb".png", image)
cv2.imshow("img", image)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## For Multiple Images

# %%
import os
if not os.path.exists('tb_bb'):
    os.makedirs('tb_bb')

# %%
def main_bb(img, xml):
    
    image = cv2.imread(img) 
    #Comment the below line if you using High-resolution(3000 × 3000) dataset.
    image = cv2.resize(image, (2840, 2827)) 
    name, boxes = read_content(xml)
    
    temp = []
    
    for i in range(len(boxes)):
        
        temp = boxes[i]
        
        start_point = (temp[0], temp[3]) 
        end_point = (temp[2], temp[1]) 
          
        
        # Change color in BGR
        if i==0:
            color = (255, 0, 0)
        if i==1:
            color = (0, 255, 0)
          
        # Line thickness of 10 px 
        thickness = 10
        
        # Using cv2.rectangle() method 
        # Draw a rectangle with blue line borders of thickness of 2 px 
        image = cv2.rectangle(image, start_point, end_point, color, thickness) 
    
    #Comment the below line if you using High-resolution(3000 × 3000) dataset.
    image = cv2.resize(image, (512, 512)) 
    
    cv2.imwrite("tb_bb/"+name+".png", image)
    # cv2.imshow("img", image)
    # cv2.waitKey(0)

# %%
path_img = "tb/"  #images path
path_xml = "xml/" #xml path

# %%
img_dirs = os.listdir( path_img )
xml_dirs = os.listdir( path_xml )


for item in img_dirs:
    if os.path.isfile(path_img+item):
        
        print("Processing image: ", item)
        fi, ei = os.path.splitext(path_img+item)
        fx, ex = os.path.splitext(path_xml+item)

        img = fi+ei
        xml = fx+".xml"

        main_bb(img, xml)
# Out:
# Processing image:  tb0003.png
# Processing image:  tb0004.png
# Processing image:  tb0005.png
# Processing image:  tb0006.png
# Processing image:  tb0007.png
# Processing image:  tb0009.png
# Processing image:  tb0012.png
# Processing image:  tb0014.png
# Processing image:  tb0015.png
# Processing image:  tb0017.png
# Processing image:  tb0018.png
# Processing image:  tb0019.png
# Processing image:  tb0020.png
# Processing image:  tb0021.png
# Processing image:  tb0024.png
# Processing image:  tb0026.png
# Processing image:  tb0027.png
# Processing image:  tb0028.png
# Processing image:  tb0029.png
# Processing image:  tb0030.png
# Processing image:  tb0031.png
# Processing image:  tb0032.png
# Processing image:  tb0033.png
# Processing image:  tb0034.png
# Processing image:  tb0036.png
# Processing image:  tb0037.png
# Processing image:  tb0040.png
# Processing image:  tb0042.png
# Processing image:  tb0043.png
# Processing image:  tb0045.png
# Processing image:  tb0047.png
# Processing image:  tb0049.png
# Processing image:  tb0050.png
# Processing image:  tb0051.png
# Processing image:  tb0052.png
# Processing image:  tb0053.png
# Processing image:  tb0054.png
# Processing image:  tb0056.png
# Processing image:  tb0057.png
# Processing image:  tb0059.png
# Processing image:  tb0062.png
# Processing image:  tb0063.png
# Processing image:  tb0065.png
# Processing image:  tb0066.png
# Processing image:  tb0068.png
# Processing image:  tb0069.png
# Processing image:  tb0071.png
# Processing image:  tb0073.png
# Processing image:  tb0075.png
# Processing image:  tb0076.png
# Processing image:  tb0077.png
# Processing image:  tb0079.png
# Processing image:  tb0080.png
# Processing image:  tb0081.png
# Processing image:  tb0082.png
# Processing image:  tb0083.png
# Processing image:  tb0084.png
# Processing image:  tb0085.png
# Processing image:  tb0086.png
# Processing image:  tb0087.png
# Processing image:  tb0088.png
# Processing image:  tb0089.png
# Processing image:  tb0090.png
# Processing image:  tb0091.png
# Processing image:  tb0092.png
# Processing image:  tb0094.png
# Processing image:  tb0095.png
# Processing image:  tb0096.png
# Processing image:  tb0098.png
# Processing image:  tb0100.png
# Processing image:  tb0103.png
# Processing image:  tb0104.png
# Processing image:  tb0107.png
# Processing image:  tb0108.png
# Processing image:  tb0114.png
# Processing image:  tb0115.png
# Processing image:  tb0117.png
# Processing image:  tb0118.png
